# %% [markdown]
# # Bacterial Population Growth Simulator

# %% [markdown]
# ## In a Spatial Structured Environment with Antibiotic Diffusion

# %% [markdown]
# ### Model

# %%
using ODE

include("Model.jl")
;

# %% [markdown]
# ### Initial Conditions

# %% [markdown]
# We declare the data types.

# %%
ant = 0:0.001:3
DR_len = length(ant)

exp_vect = Array{Float64,2}(4,DR_len)
exp_time = 0:0.1:23

for i=1:DR_len
    exp_vect[:,i] = ode23(f,[5e5,5e5,ant[i],2000],exp_time)[2][end]
end

# %% [markdown]
# We plot the growth of each strain

# %%
using Gadfly

a = exp_vect[3,:] 
bs = exp_vect[1,:] 
br = exp_vect[2,:] 

p = plot(layer(x=a, y=bs,Geom.smooth,Theme(default_color=colorant"blue")),
layer(x=a, y=br, Geom.smooth, Theme(default_color=colorant"red")),
Guide.xlabel("Antibiotic Concentration"),Guide.ylabel("Final Bacterial Density"),
    Guide.manual_color_key("Bacteria strain",
["Suceptible","Resistant"],
[colorant"blue",colorant"red"]))

dir = "../plots/model_1/"
draw(SVGJS(string(dir,"StrainsG.svg"),5inch, 5inch),p)
draw(SVGJS(5inch,5inch),p)
# Out:
# Compose.SVG(127.0mm,127.0mm,IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=182044, maxsize=Inf, ptr=182045, mark=-1),nothing,"img-c1d90a78",0,Compose.SVGPropertyFrame[],Dict{Type,Union{Compose.Property,Void}}(Pair{Type,Union{Compose.Property,Void}}(Compose.Property{Compose.SVGAttributePrimitive},nothing),Pair{Type,Union{Compose.Property,Void}}(Compose.Property{Compose.VisiblePrimitive},nothing),Pair{Type,Union{Compose.Property,Void}}(Compose.Property{Compose.FillPrimitive},nothing)),Dict{Compose.ClipPrimitive,String}(Pair{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(23.3472mm,5.0mm),(93.0722mm,5.0mm),(93.0722mm,108.708mm),(23.3472mm,108.708mm)]),"img-c1d90a78-8")),Tuple{Compose.FormPrimitive,String}[],Set{AbstractString}(),true,false,nothing,true,"img-c1d90a78-24",false,24,AbstractString["/home/rpm/.julia/v0.5/Gadfly/src/gadfly.js"],Tuple{AbstractString,AbstractString}[("Snap.svg","Snap"),("Gadfly","Gadfly")],AbstractString["fig.select(\"#img-c1d90a78-4\")\n   .drag(function() {}, function() {}, function() {});","fig.select(\"#img-c1d90a78-9\")\n   .init_gadfly();","fig.select(\"#img-c1d90a78-11\")\n   .plotroot().data(\"unfocused_ygrid_color\", \"#D0D0E0\")\n;","fig.select(\"#img-c1d90a78-11\")\n   .plotroot().data(\"focused_ygrid_color\", \"#A0A0A0\")\n;","fig.select(\"#img-c1d90a78-12\")\n   .plotroot().data(\"unfocused_xgrid_color\", \"#D0D0E0\")\n;","fig.select(\"#img-c1d90a78-12\")\n   .plotroot().data(\"focused_xgrid_color\", \"#A0A0A0\")\n;","fig.select(\"#img-c1d90a78-17\")\n   .data(\"mouseover_color\", \"#CD5C5C\")\n;","fig.select(\"#img-c1d90a78-17\")\n   .data(\"mouseout_color\", \"#6A6A6A\")\n;","fig.select(\"#img-c1d90a78-17\")\n   .click(Gadfly.zoomslider_zoomin_click)\n.mouseenter(Gadfly.zoomslider_button_mouseover)\n.mouseleave(Gadfly.zoomslider_button_mouseout)\n;","fig.select(\"#img-c1d90a78-19\")\n   .data(\"max_pos\", 77.07)\n;","fig.select(\"#img-c1d90a78-19\")\n   .data(\"min_pos\", 60.07)\n;","fig.select(\"#img-c1d90a78-19\")\n   .click(Gadfly.zoomslider_track_click);","fig.select(\"#img-c1d90a78-20\")\n   .data(\"max_pos\", 77.07)\n;","fig.select(\"#img-c1d90a78-20\")\n   .data(\"min_pos\", 60.07)\n;","fig.select(\"#img-c1d90a78-20\")\n   .data(\"mouseover_color\", \"#CD5C5C\")\n;","fig.select(\"#img-c1d90a78-20\")\n   .data(\"mouseout_color\", \"#6A6A6A\")\n;","fig.select(\"#img-c1d90a78-20\")\n   .drag(Gadfly.zoomslider_thumb_dragmove,\n     Gadfly.zoomslider_thumb_dragstart,\n     Gadfly.zoomslider_thumb_dragend)\n;","fig.select(\"#img-c1d90a78-21\")\n   .data(\"mouseover_color\", \"#CD5C5C\")\n;","fig.select(\"#img-c1d90a78-21\")\n   .data(\"mouseout_color\", \"#6A6A6A\")\n;","fig.select(\"#img-c1d90a78-21\")\n   .click(Gadfly.zoomslider_zoomout_click)\n.mouseenter(Gadfly.zoomslider_button_mouseover)\n.mouseleave(Gadfly.zoomslider_button_mouseout)\n;"],true,:embed)

# %% [markdown]
# Ploteamos el fitness relativo con respecto a la concentración inicial de antibiótico en el microambiente.

# %%
FRF = [br[i]/(br[i]+bs[i]) for i=1:DR_len]

p = plot(x = a, y = FRF, Geom.smooth,
    Guide.xlabel("Antibiotic Concentration"),
Guide.ylabel("Final Resistant OD / Final Suceptible OD"),
Guide.Title("Relative fitness"))
draw(SVGJS(string(dir,"RelativeFitness.svg"),5inch, 5inch),p)
draw(SVGJS(5inch,5inch),p)
# Out:
# Compose.SVG(127.0mm,127.0mm,IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=171499, maxsize=Inf, ptr=171500, mark=-1),nothing,"img-500a3652",0,Compose.SVGPropertyFrame[],Dict{Type,Union{Compose.Property,Void}}(Pair{Type,Union{Compose.Property,Void}}(Compose.Property{Compose.SVGAttributePrimitive},nothing),Pair{Type,Union{Compose.Property,Void}}(Compose.Property{Compose.VisiblePrimitive},nothing)),Dict{Compose.ClipPrimitive,String}(Pair{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(19.1139mm,9.82222mm),(122.0mm,9.82222mm),(122.0mm,108.708mm),(19.1139mm,108.708mm)]),"img-500a3652-4")),Tuple{Compose.FormPrimitive,String}[],Set{AbstractString}(),true,false,nothing,true,"img-500a3652-20",false,20,AbstractString["/home/rpm/.julia/v0.5/Gadfly/src/gadfly.js"],Tuple{AbstractString,AbstractString}[("Snap.svg","Snap"),("Gadfly","Gadfly")],AbstractString["fig.select(\"#img-500a3652-5\")\n   .init_gadfly();","fig.select(\"#img-500a3652-7\")\n   .plotroot().data(\"unfocused_ygrid_color\", \"#D0D0E0\")\n;","fig.select(\"#img-500a3652-7\")\n   .plotroot().data(\"focused_ygrid_color\", \"#A0A0A0\")\n;","fig.select(\"#img-500a3652-8\")\n   .plotroot().data(\"unfocused_xgrid_color\", \"#D0D0E0\")\n;","fig.select(\"#img-500a3652-8\")\n   .plotroot().data(\"focused_xgrid_color\", \"#A0A0A0\")\n;","fig.select(\"#img-500a3652-12\")\n   .data(\"mouseover_color\", \"#CD5C5C\")\n;","fig.select(\"#img-500a3652-12\")\n   .data(\"mouseout_color\", \"#6A6A6A\")\n;","fig.select(\"#img-500a3652-12\")\n   .click(Gadfly.zoomslider_zoomin_click)\n.mouseenter(Gadfly.zoomslider_button_mouseover)\n.mouseleave(Gadfly.zoomslider_button_mouseout)\n;","fig.select(\"#img-500a3652-14\")\n   .data(\"max_pos\", 106)\n;","fig.select(\"#img-500a3652-14\")\n   .data(\"min_pos\", 89)\n;","fig.select(\"#img-500a3652-14\")\n   .click(Gadfly.zoomslider_track_click);","fig.select(\"#img-500a3652-15\")\n   .data(\"max_pos\", 106)\n;","fig.select(\"#img-500a3652-15\")\n   .data(\"min_pos\", 89)\n;","fig.select(\"#img-500a3652-15\")\n   .data(\"mouseover_color\", \"#CD5C5C\")\n;","fig.select(\"#img-500a3652-15\")\n   .data(\"mouseout_color\", \"#6A6A6A\")\n;","fig.select(\"#img-500a3652-15\")\n   .drag(Gadfly.zoomslider_thumb_dragmove,\n     Gadfly.zoomslider_thumb_dragstart,\n     Gadfly.zoomslider_thumb_dragend)\n;","fig.select(\"#img-500a3652-16\")\n   .data(\"mouseover_color\", \"#CD5C5C\")\n;","fig.select(\"#img-500a3652-16\")\n   .data(\"mouseout_color\", \"#6A6A6A\")\n;","fig.select(\"#img-500a3652-16\")\n   .click(Gadfly.zoomslider_zoomout_click)\n.mouseenter(Gadfly.zoomslider_button_mouseover)\n.mouseleave(Gadfly.zoomslider_button_mouseout)\n;"],true,:embed)

# %%
tmp = FRF[1]
a_index = 0
for i=1:DR_len
    if(FRF[i] <= 0.501 && FRF[i]>tmp)
        tmp = FRF[i]
        a_index = i
    end
end

print("Concentración de antibiótico para punto de inflexión: ", exp_vect[3,a_index])
# Out:
# Concentración de antibiótico para punto de inflexión: 0.765

# %% [markdown]
# We plot them again but with the  turnover value included

# %%
p = plot(layer(x=a, y=bs,Geom.smooth,Theme(default_color=colorant"blue")),
layer(x=a, y=br, Geom.smooth, Theme(default_color=colorant"red")),
Guide.xlabel("Antibiotic Concentration"),Guide.ylabel("Final OD"),
Guide.title("Single node competition under different antibiotic concentrations"), Guide.manual_color_key("Bacteria strain", 
["Suceptible","Resistant"],
[colorant"blue",colorant"red"]),
xintercept=[exp_vect[3,a_index]],Geom.vline)
draw(SVGJS(string(dir,"RelativeFitness_aast.svg"),10inch, 15inch),p)
draw(SVGJS(5inch,4inch),p)
# Out:
# Compose.SVG(127.0mm,101.6mm,IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=181960, maxsize=Inf, ptr=181961, mark=-1),nothing,"img-e2307a51",0,Compose.SVGPropertyFrame[],Dict{Type,Union{Compose.Property,Void}}(Pair{Type,Union{Compose.Property,Void}}(Compose.Property{Compose.SVGAttributePrimitive},nothing),Pair{Type,Union{Compose.Property,Void}}(Compose.Property{Compose.VisiblePrimitive},nothing),Pair{Type,Union{Compose.Property,Void}}(Compose.Property{Compose.FillPrimitive},nothing)),Dict{Compose.ClipPrimitive,String}(Pair{Compose.ClipPrimitive,String}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}[(22.6417mm,10.5278mm),(93.0722mm,10.5278mm),(93.0722mm,83.3083mm),(22.6417mm,83.3083mm)]),"img-e2307a51-8")),Tuple{Compose.FormPrimitive,String}[],Set{AbstractString}(),true,false,nothing,true,"img-e2307a51-26",false,26,AbstractString["/home/rpm/.julia/v0.5/Gadfly/src/gadfly.js"],Tuple{AbstractString,AbstractString}[("Snap.svg","Snap"),("Gadfly","Gadfly")],AbstractString["fig.select(\"#img-e2307a51-4\")\n   .drag(function() {}, function() {}, function() {});","fig.select(\"#img-e2307a51-9\")\n   .init_gadfly();","fig.select(\"#img-e2307a51-11\")\n   .plotroot().data(\"unfocused_ygrid_color\", \"#D0D0E0\")\n;","fig.select(\"#img-e2307a51-11\")\n   .plotroot().data(\"focused_ygrid_color\", \"#A0A0A0\")\n;","fig.select(\"#img-e2307a51-12\")\n   .plotroot().data(\"unfocused_xgrid_color\", \"#D0D0E0\")\n;","fig.select(\"#img-e2307a51-12\")\n   .plotroot().data(\"focused_xgrid_color\", \"#A0A0A0\")\n;","fig.select(\"#img-e2307a51-18\")\n   .data(\"mouseover_color\", \"#CD5C5C\")\n;","fig.select(\"#img-e2307a51-18\")\n   .data(\"mouseout_color\", \"#6A6A6A\")\n;","fig.select(\"#img-e2307a51-18\")\n   .click(Gadfly.zoomslider_zoomin_click)\n.mouseenter(Gadfly.zoomslider_button_mouseover)\n.mouseleave(Gadfly.zoomslider_button_mouseout)\n;","fig.select(\"#img-e2307a51-20\")\n   .data(\"max_pos\", 77.07)\n;","fig.select(\"#img-e2307a51-20\")\n   .data(\"min_pos\", 60.07)\n;","fig.select(\"#img-e2307a51-20\")\n   .click(Gadfly.zoomslider_track_click);","fig.select(\"#img-e2307a51-21\")\n   .data(\"max_pos\", 77.07)\n;","fig.select(\"#img-e2307a51-21\")\n   .data(\"min_pos\", 60.07)\n;","fig.select(\"#img-e2307a51-21\")\n   .data(\"mouseover_color\", \"#CD5C5C\")\n;","fig.select(\"#img-e2307a51-21\")\n   .data(\"mouseout_color\", \"#6A6A6A\")\n;","fig.select(\"#img-e2307a51-21\")\n   .drag(Gadfly.zoomslider_thumb_dragmove,\n     Gadfly.zoomslider_thumb_dragstart,\n     Gadfly.zoomslider_thumb_dragend)\n;","fig.select(\"#img-e2307a51-22\")\n   .data(\"mouseover_color\", \"#CD5C5C\")\n;","fig.select(\"#img-e2307a51-22\")\n   .data(\"mouseout_color\", \"#6A6A6A\")\n;","fig.select(\"#img-e2307a51-22\")\n   .click(Gadfly.zoomslider_zoomout_click)\n.mouseenter(Gadfly.zoomslider_button_mouseover)\n.mouseleave(Gadfly.zoomslider_button_mouseout)\n;"],true,:embed)

# %%
br[762]
# Out:
# 6.474323538689386e6

# %%
exp_vect[2,763]/(exp_vect[2,763]+exp_vect[1,763])
exp_vect[:,763]
# Out:
# 4-element Array{Float64,1}:
#     6.46408e6
#     6.46688e6
#     0.762
#  1094.08

# %%
fitness = [br[i]/(br[i]+bs[i]) for i in eachindex(br)]

plot(x = a, y = fitness, Geom.smooth,
    Guide.xlabel("Antibiotic Concentration"),
    Guide.ylabel("OD_r(t=24) / OD_s(t=24)"),
Guide.Title("Final Relative fitness"),
xintercept=[exp_vect[a_time][3]],Geom.vline(color=colorant"red"))#,
#yintercept=1,Geom.hline(color=colorant"green"))
# Out:
# LoadError: UndefVarError: a_time not defined
# while loading In[8], in expression starting on line 3
