# %%
using ODE, Colors, Compose

# %%
include("source/Model.jl")
include("source/Plotter.jl")
include("source/Functions.jl")
;
# Out:
# WARNING: Method definition (::Type{Main.bact})(Float64, Float64, Float64, Float64, Float64) in module Main at /home/rpm/STARAS/Networks/Grid_Simulator/source/Model.jl:5 overwritten at /home/rpm/STARAS/Networks/Grid_Simulator/source/Model.jl:5.
# WARNING: Method definition (::Type{Main.bact})(Any, Any, Any, Any, Any) in module Main at /home/rpm/STARAS/Networks/Grid_Simulator/source/Model.jl:5 overwritten at /home/rpm/STARAS/Networks/Grid_Simulator/source/Model.jl:5.
# WARNING: Method definition (::Type{Main.antb})(Float64) in module Main at /home/rpm/STARAS/Networks/Grid_Simulator/source/Model.jl:13 overwritten at /home/rpm/STARAS/Networks/Grid_Simulator/source/Model.jl:13.
# WARNING: Method definition (::Type{Main.antb})(Any) in module Main at /home/rpm/STARAS/Networks/Grid_Simulator/source/Model.jl:13 overwritten at /home/rpm/STARAS/Networks/Grid_Simulator/source/Model.jl:13.
# ...

# %%
lane_num = 6
col_num = 6
ant_to_node = 6.
d0, con_mat = create_grid(lane_num,col_num);

# %%
res = iter(declare_darray(d0),con_mat);

# %%
grid_plot = plot_grid(res,lane_num)
draw(PNG("plots/Grid6x6.png",40cm,40cm),grid_plot)
display(grid_plot)
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w,0.0h),(1.0w,1.0h)),Nullable{Compose.UnitBox{S,T,U,V}}(),Nullable{Compose.Rotation{P<:Tuple{Vararg{Measures.Measure,N}}}}(),Nullable{Compose.Mirror}(),List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w,0.0h),(1.0w,1.0h)),Nullable{Compose.UnitBox{S,T,U,V}}(),Nullable{Compose.Rotation{P<:Tuple{Vararg{Measures.Measure,N}}}}(),Nullable{Compose.Mirror}(),List([]),List([Compose.Form{Compose.TextPrimitive{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Compose.Rotation{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}}}(Compose.TextPrimitive{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Compose.Rotation{Tuple{Measures.Length{:w,Float64},Measures.Length{
# ...
